# %%
import pandas as pd
import json
import numpy as np

# %%
df = pd.read_csv("FOI 1760 2021/FOI 1760-2021.csv", low_memory = False)

# %%
df.head()
# Out:
#   Travel Location Name  Travel Location No Transport Mode       Travel Date  \
# 0       Abbey Road DLR                 750           Rail  01/01/2020 00:00
# 1       Abbey Road DLR                 750           Rail  01/01/2020 00:00
# 2       Abbey Road DLR                 750           Rail  01/01/2020 00:00
# 3       Abbey Road DLR                 750           Rail  02/01/2020 00:00
# 4       Abbey Road DLR                 750           Rail  02/01/2020 00:00
#
#   Transaction Type  Count of Taps
# 0             Exit            224
# 1             PVal            230
# 2            Entry            229
# 3             Exit            406
# 4             PVal            552

# %%
df = df[df['Transport Mode'] == "Rail" ]

# %%
df.rename(columns={'Count of Taps':'Amount'}, inplace=True)
df["Travel Date"] = pd.to_datetime(df["Travel Date"])
dfs = df.groupby(["Travel Date", "Travel Location Name"]).Amount.sum().reset_index()
# dfs = dfs.groupby(dfs.index.week).cumsum().reset_index()
dfs
# Out:
#        Travel Date  Travel Location Name  Amount
# 0       2020-01-01        Abbey Road DLR     683
# 1       2020-01-01            Abbey Wood    3035
# 2       2020-01-01         Acton Central    1962
# 3       2020-01-01       Acton Main Line     242
# 4       2020-01-01            Acton Town    7355
# ...            ...                   ...     ...
# 218136  2020-12-11         Woodside Park    2747
# 218137  2020-12-11  Woolwich Arsenal DLR   13720
# 218138  2020-12-11   Woolwich Arsenal NR    5271
# 218139  2020-12-11     Woolwich Dockyard     617
# 218140  2020-12-11        Worcester Park    1376
#
# [218141 rows x 3 columns]

# %%
dfs['Amount']=np.round(dfs['Amount']/1000)

# %%
# first lockdown 23 mar, week before
dfs["Travel Date"] = pd.to_datetime(dfs["Travel Date"])
before_ld1 = dfs[(dfs["Travel Date"] >= '2020-03-16 00:00:00') & (dfs["Travel Date"] < '2020-03-23 00:00:00')]
before_ld1 = before_ld1.groupby(["Travel Location Name"]).Amount.mean().reset_index()

# %%
# first lockdown 23 mar, week after
after_ld1 = dfs[(dfs["Travel Date"] >= '2020-03-23 00:00:00') & (dfs["Travel Date"] < '2020-03-30 00:00:00')]
after_ld1 = after_ld1.groupby(["Travel Location Name"]).Amount.mean().reset_index()

# %%
# second lockdown 5 nov, week before
before_ld2 = dfs[(dfs["Travel Date"] >= '2020-10-29 00:00:00') & (dfs["Travel Date"] < '2020-11-05 00:00:00')]
before_ld2 = before_ld2.groupby(["Travel Location Name"]).Amount.mean().reset_index()

# %%
# second lockdown 5 nov, week after
after_ld2 = dfs[(dfs["Travel Date"] >= '2020-11-05 00:00:00') & (dfs["Travel Date"] < '2020-11-12 00:00:00')]
after_ld2 = after_ld2.groupby(["Travel Location Name"]).Amount.mean().reset_index()

# %%
# import pprint

with open('tfl_stations.json') as f:
  stations = json.load(f)

# print(json.dumps(stations, allow_nan = True,
#                          indent = 6))
# pprint.pprint(stations)

# %%
stations_df = pd.json_normalize(stations["features"])

# %%
stations_df.head()
# Out:
#       type properties.id properties.name properties.nlc_id  \
# 0  Feature   940GZZLUACT      Acton Town              0500
# 1  Feature   940GZZLUACY         Archway              0508
# 2  Feature   940GZZLUADE    Aldgate East              0503
# 3  Feature   940GZZLUAGL           Angel              0507
# 4  Feature   940GZZLUALD         Aldgate              0502
#
#                                     properties.lines  \
# 0  [{'name': 'District'}, {'name': 'Piccadilly', ...
# 1        [{'name': 'Northern', 'nightopened': 2016}]
# 2  [{'name': 'District'}, {'name': 'Hammersmith &...
# 3  [{'name': 'Northern'}, {'name': 'Crossrail 2',...
# 4     [{'name': 'Circle'}, {'name': 'Metropolitan'}]
#
#    properties.cartography.labelX properties.alt_id properties.zone  \
# 0                             30                 1               3
# 1                            -30                 8             2/3
# 2                             30                 3               1
# 3                              1                 7               1
# 4                             25                 2               1
#
#   geometry.type                      geometry.coordinates  \
# 0         Point   [-0.279916688851386, 51.50264359676248]
# 1         Point  [-0.134745288767581, 51.565370996797775]
# 2         Point   [-0.071876588767481, 51.51514719676551]
# 3         Point    [-0.10612998877245, 51.53182149677656]
# 4         Point   [-0.075715588769394, 51.51409639676498]
#
#    properties.cartography.labelY properties.cartography.display_name  \
# 0                            NaN                                 NaN
# 1                            NaN                                 NaN
# 2                            NaN                                 NaN
# 3                          -35.0                                 NaN
# 4                           20.0                                 NaN
#
#   properties.altmodeid properties.altmodeid2
# 0                  NaN                   NaN
# 1                  NaN                   NaN
# 2                  NaN                   NaN
# 3                  NaN                   NaN
# 4                  NaN                   NaN

# %%
before_ld1.rename(columns={'Travel Location Name':'properties.name'}, inplace=True)

# %%
before_ld1.head()
# Out:
#    properties.name    Amount
# 0   Abbey Road DLR  0.714286
# 1       Abbey Wood  5.428571
# 2    Acton Central  2.571429
# 3  Acton Main Line  0.285714
# 4       Acton Town  7.714286

# %%
after_ld1.rename(columns={'Travel Location Name':'properties.name'}, inplace=True)
before_ld2.rename(columns={'Travel Location Name':'properties.name'}, inplace=True)
after_ld2.rename(columns={'Travel Location Name':'properties.name'}, inplace=True)

# %%
df_final = pd.merge(before_ld1, stations_df, how='right',on = 'properties.name')
df_final.head()
# Out:
#   properties.name     Amount     type properties.id properties.nlc_id  \
# 0      Acton Town   7.714286  Feature   940GZZLUACT              0500
# 1         Archway   9.142857  Feature   940GZZLUACY              0508
# 2    Aldgate East   9.714286  Feature   940GZZLUADE              0503
# 3           Angel  12.285714  Feature   940GZZLUAGL              0507
# 4         Aldgate  11.000000  Feature   940GZZLUALD              0502
#
#                                     properties.lines  \
# 0  [{'name': 'District'}, {'name': 'Piccadilly', ...
# 1        [{'name': 'Northern', 'nightopened': 2016}]
# 2  [{'name': 'District'}, {'name': 'Hammersmith &...
# 3  [{'name': 'Northern'}, {'name': 'Crossrail 2',...
# 4     [{'name': 'Circle'}, {'name': 'Metropolitan'}]
#
#    properties.cartography.labelX properties.alt_id properties.zone  \
# 0                             30                 1               3
# 1                            -30                 8             2/3
# 2                             30                 3               1
# 3                              1                 7               1
# 4                             25                 2               1
#
#   geometry.type                      geometry.coordinates  \
# 0         Point   [-0.279916688851386, 51.50264359676248]
# 1         Point  [-0.134745288767581, 51.565370996797775]
# 2         Point   [-0.071876588767481, 51.51514719676551]
# 3         Point    [-0.10612998877245, 51.53182149677656]
# 4         Point   [-0.075715588769394, 51.51409639676498]
#
#    properties.cartography.labelY properties.cartography.display_name  \
# 0                            NaN                                 NaN
# 1                            NaN                                 NaN
# 2                            NaN                                 NaN
# 3                          -35.0                                 NaN
# 4                           20.0                                 NaN
#
#   properties.altmodeid properties.altmodeid2
# 0                  NaN                   NaN
# 1                  NaN                   NaN
# 2                  NaN                   NaN
# 3                  NaN                   NaN
# 4                  NaN                   NaN

# %%
df_final.rename(columns={'Amount':'properties.beforeld1'}, inplace=True)

# %%
df_final_copy = df_final

# %%
df_final = pd.merge(after_ld1, df_final, how='right',on = 'properties.name')
df_final.head()
# Out:
#   properties.name    Amount  properties.beforeld1     type properties.id  \
# 0      Acton Town  2.285714              7.714286  Feature   940GZZLUACT
# 1         Archway  2.571429              9.142857  Feature   940GZZLUACY
# 2    Aldgate East  2.000000              9.714286  Feature   940GZZLUADE
# 3           Angel  2.285714             12.285714  Feature   940GZZLUAGL
# 4         Aldgate  1.142857             11.000000  Feature   940GZZLUALD
#
#   properties.nlc_id                                   properties.lines  \
# 0              0500  [{'name': 'District'}, {'name': 'Piccadilly', ...
# 1              0508        [{'name': 'Northern', 'nightopened': 2016}]
# 2              0503  [{'name': 'District'}, {'name': 'Hammersmith &...
# 3              0507  [{'name': 'Northern'}, {'name': 'Crossrail 2',...
# 4              0502     [{'name': 'Circle'}, {'name': 'Metropolitan'}]
#
#    properties.cartography.labelX properties.alt_id properties.zone  \
# 0                             30                 1               3
# 1                            -30                 8             2/3
# 2                             30                 3               1
# 3                              1                 7               1
# 4                             25                 2               1
#
#   geometry.type                      geometry.coordinates  \
# 0         Point   [-0.279916688851386, 51.50264359676248]
# 1         Point  [-0.134745288767581, 51.565370996797775]
# 2         Point   [-0.071876588767481, 51.51514719676551]
# 3         Point    [-0.10612998877245, 51.53182149677656]
# 4         Point   [-0.075715588769394, 51.51409639676498]
#
#    properties.cartography.labelY properties.cartography.display_name  \
# 0                            NaN                                 NaN
# 1                            NaN                                 NaN
# 2                            NaN                                 NaN
# 3                          -35.0                                 NaN
# 4                           20.0                                 NaN
#
#   properties.altmodeid properties.altmodeid2
# 0                  NaN                   NaN
# 1                  NaN                   NaN
# 2                  NaN                   NaN
# 3                  NaN                   NaN
# 4                  NaN                   NaN

# %%
df_final.rename(columns={'Amount':'properties.afterld1'}, inplace=True)

# %%
df_final = pd.merge(before_ld2, df_final, how='right',on = 'properties.name')
df_final.rename(columns={'Amount':'properties.beforeld2'}, inplace=True)
df_final.head()
# Out:
#   properties.name  properties.beforeld2  properties.afterld1  \
# 0      Acton Town             10.857143             2.285714
# 1         Archway             15.142857             2.571429
# 2    Aldgate East             19.714286             2.000000
# 3           Angel             28.285714             2.285714
# 4         Aldgate             13.000000             1.142857
#
#    properties.beforeld1     type properties.id properties.nlc_id  \
# 0              7.714286  Feature   940GZZLUACT              0500
# 1              9.142857  Feature   940GZZLUACY              0508
# 2              9.714286  Feature   940GZZLUADE              0503
# 3             12.285714  Feature   940GZZLUAGL              0507
# 4             11.000000  Feature   940GZZLUALD              0502
#
#                                     properties.lines  \
# 0  [{'name': 'District'}, {'name': 'Piccadilly', ...
# 1        [{'name': 'Northern', 'nightopened': 2016}]
# 2  [{'name': 'District'}, {'name': 'Hammersmith &...
# 3  [{'name': 'Northern'}, {'name': 'Crossrail 2',...
# 4     [{'name': 'Circle'}, {'name': 'Metropolitan'}]
#
#    properties.cartography.labelX properties.alt_id properties.zone  \
# 0                             30                 1               3
# 1                            -30                 8             2/3
# 2                             30                 3               1
# 3                              1                 7               1
# 4                             25                 2               1
#
#   geometry.type                      geometry.coordinates  \
# 0         Point   [-0.279916688851386, 51.50264359676248]
# 1         Point  [-0.134745288767581, 51.565370996797775]
# 2         Point   [-0.071876588767481, 51.51514719676551]
# 3         Point    [-0.10612998877245, 51.53182149677656]
# 4         Point   [-0.075715588769394, 51.51409639676498]
#
#    properties.cartography.labelY properties.cartography.display_name  \
# 0                            NaN                                 NaN
# 1                            NaN                                 NaN
# 2                            NaN                                 NaN
# 3                          -35.0                                 NaN
# 4                           20.0                                 NaN
#
#   properties.altmodeid properties.altmodeid2
# 0                  NaN                   NaN
# 1                  NaN                   NaN
# 2                  NaN                   NaN
# 3                  NaN                   NaN
# 4                  NaN                   NaN

# %%
df_final = pd.merge(after_ld2, df_final, how='right',on = 'properties.name')
df_final.rename(columns={'Amount':'properties.afterld2'}, inplace=True)
df_final.head()
# Out:
#   properties.name  properties.afterld2  properties.beforeld2  \
# 0      Acton Town             5.428571             10.857143
# 1         Archway             7.000000             15.142857
# 2    Aldgate East             5.800000             19.714286
# 3           Angel             9.000000             28.285714
# 4         Aldgate             4.714286             13.000000
#
#    properties.afterld1  properties.beforeld1     type properties.id  \
# 0             2.285714              7.714286  Feature   940GZZLUACT
# 1             2.571429              9.142857  Feature   940GZZLUACY
# 2             2.000000              9.714286  Feature   940GZZLUADE
# 3             2.285714             12.285714  Feature   940GZZLUAGL
# 4             1.142857             11.000000  Feature   940GZZLUALD
#
#   properties.nlc_id                                   properties.lines  \
# 0              0500  [{'name': 'District'}, {'name': 'Piccadilly', ...
# 1              0508        [{'name': 'Northern', 'nightopened': 2016}]
# 2              0503  [{'name': 'District'}, {'name': 'Hammersmith &...
# 3              0507  [{'name': 'Northern'}, {'name': 'Crossrail 2',...
# 4              0502     [{'name': 'Circle'}, {'name': 'Metropolitan'}]
#
#    properties.cartography.labelX properties.alt_id properties.zone  \
# 0                             30                 1               3
# 1                            -30                 8             2/3
# 2                             30                 3               1
# 3                              1                 7               1
# 4                             25                 2               1
#
#   geometry.type                      geometry.coordinates  \
# 0         Point   [-0.279916688851386, 51.50264359676248]
# 1         Point  [-0.134745288767581, 51.565370996797775]
# 2         Point   [-0.071876588767481, 51.51514719676551]
# 3         Point    [-0.10612998877245, 51.53182149677656]
# 4         Point   [-0.075715588769394, 51.51409639676498]
#
#    properties.cartography.labelY properties.cartography.display_name  \
# 0                            NaN                                 NaN
# 1                            NaN                                 NaN
# 2                            NaN                                 NaN
# 3                          -35.0                                 NaN
# 4                           20.0                                 NaN
#
#   properties.altmodeid properties.altmodeid2
# 0                  NaN                   NaN
# 1                  NaN                   NaN
# 2                  NaN                   NaN
# 3                  NaN                   NaN
# 4                  NaN                   NaN

# %%
df_final = df_final[['type', 'properties.id', 'properties.name', 'properties.nlc_id', 'properties.lines', 
                     'properties.cartography.labelX', 'properties.cartography.labelY', 'properties.cartography.display_name',
                     'properties.altmodeid', 'properties.altmodeid2', 'properties.alt_id', 'properties.zone', 
                     'properties.beforeld1', 'properties.afterld1', 'properties.beforeld2','properties.afterld2',
                     'geometry.type', 'geometry.coordinates'
                    ]]
# {'crs': {'properties': {'name': 'urn:ogc:def:crs:OGC:1.3:CRS84'},
#          'type': 'name'},
#  'features': [{'geometry': {'coordinates': [-0.279916688851386,
#                                             51.50264359676248],
#                             'type': 'Point'},
#                'properties': {'alt_id': 1,
#                               'cartography': {'labelX': 30},
#                               'id': '940GZZLUACT',
#                               'lines': [{'name': 'District'},
#                                         {'name': 'Piccadilly',
#                                          'nightopened': 2016}],
#                               'name': 'Acton Town',
#                               'nlc_id': '0500',
#                               'zone': '3'},
#                'type': 'Feature'},

# %%
df_final.head()
# Out:
#       type properties.id properties.name properties.nlc_id  \
# 0  Feature   940GZZLUACT      Acton Town              0500
# 1  Feature   940GZZLUACY         Archway              0508
# 2  Feature   940GZZLUADE    Aldgate East              0503
# 3  Feature   940GZZLUAGL           Angel              0507
# 4  Feature   940GZZLUALD         Aldgate              0502
#
#                                     properties.lines  \
# 0  [{'name': 'District'}, {'name': 'Piccadilly', ...
# 1        [{'name': 'Northern', 'nightopened': 2016}]
# 2  [{'name': 'District'}, {'name': 'Hammersmith &...
# 3  [{'name': 'Northern'}, {'name': 'Crossrail 2',...
# 4     [{'name': 'Circle'}, {'name': 'Metropolitan'}]
#
#    properties.cartography.labelX  properties.cartography.labelY  \
# 0                             30                            NaN
# 1                            -30                            NaN
# 2                             30                            NaN
# 3                              1                          -35.0
# 4                             25                           20.0
#
#   properties.cartography.display_name properties.altmodeid  \
# 0                                 NaN                  NaN
# 1                                 NaN                  NaN
# 2                                 NaN                  NaN
# 3                                 NaN                  NaN
# 4                                 NaN                  NaN
#
#   properties.altmodeid2 properties.alt_id properties.zone  \
# 0                   NaN                 1               3
# 1                   NaN                 8             2/3
# 2                   NaN                 3               1
# 3                   NaN                 7               1
# 4                   NaN                 2               1
#
#    properties.beforeld1  properties.afterld1  properties.beforeld2  \
# 0              7.714286             2.285714             10.857143
# 1              9.142857             2.571429             15.142857
# 2              9.714286             2.000000             19.714286
# 3             12.285714             2.285714             28.285714
# 4             11.000000             1.142857             13.000000
#
#    properties.afterld2 geometry.type                      geometry.coordinates
# 0             5.428571         Point   [-0.279916688851386, 51.50264359676248]
# 1             7.000000         Point  [-0.134745288767581, 51.565370996797775]
# 2             5.800000         Point   [-0.071876588767481, 51.51514719676551]
# 3             9.000000         Point    [-0.10612998877245, 51.53182149677656]
# 4             4.714286         Point   [-0.075715588769394, 51.51409639676498]

# %%
df_final = df_final.replace(np.nan, '') # All data frame

# %%
def df_to_formatted_json(df, sep="."):
    """
    The opposite of json_normalize
    """
    result = []
    for idx, row in df.iterrows():
        parsed_row = {}
        for col_label,v in row.items():
            keys = col_label.split(".")

            current = parsed_row
            for i, k in enumerate(keys):
                if i==len(keys)-1:
                    current[k] = v
                else:
                    if k not in current.keys():
                        current[k] = {}
                    current = current[k]
        # save
        result.append(parsed_row)
    return result

# %%
df_feature= df_to_formatted_json(df_final)

# %%
df_dict= {"type": "FeatureCollection",
#           "crs": {
#               "type": "name",
#               "properties": {
#                   "name": "urn:ogc:def:crs:OGC:1.3:CRS84"
#             }
#           }
         }
df_dict['features'] = df_feature
# df_json = json.dumps(df_dict)
# df_json = json.loads(df_dict)

with open('footfall.json', 'w') as fp:
    json.dump(df_dict, fp)
#     simplejson.dumps(df_dict, fp,ignore_nan=True)

# %%
# df_feature1 = df_feature.replace(np.nan, '') # All data frame


# df_feature1=['' if x is np.nan else x for x in df_feature]

# %%
# df_final.to_csv("before_lk1.csv")

# %%
df_final.head()
# Out:
#       type properties.id properties.name properties.nlc_id  \
# 0  Feature   940GZZLUACT      Acton Town              0500
# 1  Feature   940GZZLUACY         Archway              0508
# 2  Feature   940GZZLUADE    Aldgate East              0503
# 3  Feature   940GZZLUAGL           Angel              0507
# 4  Feature   940GZZLUALD         Aldgate              0502
#
#                                     properties.lines  \
# 0  [{'name': 'District'}, {'name': 'Piccadilly', ...
# 1        [{'name': 'Northern', 'nightopened': 2016}]
# 2  [{'name': 'District'}, {'name': 'Hammersmith &...
# 3  [{'name': 'Northern'}, {'name': 'Crossrail 2',...
# 4     [{'name': 'Circle'}, {'name': 'Metropolitan'}]
#
#    properties.cartography.labelX properties.cartography.labelY  \
# 0                             30
# 1                            -30
# 2                             30
# 3                              1                           -35
# 4                             25                            20
#
#   properties.cartography.display_name properties.altmodeid  \
# 0
# 1
# 2
# 3
# 4
#
#   properties.altmodeid2 properties.alt_id properties.zone  \
# 0                                       1               3
# 1                                       8             2/3
# 2                                       3               1
# 3                                       7               1
# 4                                       2               1
#
#   properties.beforeld1 properties.afterld1 properties.beforeld2  \
# 0              7.71429             2.28571              10.8571
# 1              9.14286             2.57143              15.1429
# 2              9.71429                   2              19.7143
# 3              12.2857             2.28571              28.2857
# 4                   11             1.14286                   13
#
#   properties.afterld2 geometry.type                      geometry.coordinates
# 0             5.42857         Point   [-0.279916688851386, 51.50264359676248]
# 1                   7         Point  [-0.134745288767581, 51.565370996797775]
# 2                 5.8         Point   [-0.071876588767481, 51.51514719676551]
# 3                   9         Point    [-0.10612998877245, 51.53182149677656]
# 4             4.71429         Point   [-0.075715588769394, 51.51409639676498]

# %%
data = pd.read_csv("applemobilitytrends-2021-03-22_london.csv", encoding="ISO-8859-1", low_memory=False)

# %%
data=data.loc[data['region'] == "London"].transpose().iloc[2:]

# %%
data = data.rename(columns=data.iloc[0])
data=data.iloc[4:]

# %%
data.head()
# Out:
#           driving transit walking
# 2020/1/13     100     100     100
# 2020/1/14  107.65  105.14  108.89
# 2020/1/15   111.2  107.06  116.84
# 2020/1/16  108.29  106.08  118.82
# 2020/1/17  115.08  115.13  132.18

# %%
data['date'] = data.index
data = data.reset_index()
data = data.drop("index", axis = 1)

# %%
# from dateutil import parser
# date_col = []
# for i in data["date"]:
#   date_col.append(parser.parse(data.date[i])) 
# # data["datetime"][i]

# %%
x = data.index
y = data.driving
df = pd.DataFrame(data=y,index=x)

# %%
import numpy as np
test_pecent = 0.16667 
len(df)*test_pecent
test_point = np.round(len(df)*test_pecent) 
test_index = int(len(df) - test_point) 
train = df.iloc[:test_index]
test = df.iloc[test_index:]

plt.figure(figsize=(12,8))
plt.xlim(0, 60)

print(len(df)) # 601
print(len(train))
print(len(test))
#train.plot()
#test.plot()
plt.plot(train)
plt.plot(test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-fbd12960cd55> in <module>
#       7 test = df.iloc[test_index:]
#       8
# ----> 9 plt.figure(figsize=(12,8))
#      10 plt.xlim(0, 60)
#      11
#
# NameError: name 'plt' is not defined
